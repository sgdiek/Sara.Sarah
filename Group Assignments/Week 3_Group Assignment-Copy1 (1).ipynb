# %%
import pandas as pd

# %%
# Relative file path to upload data
children = pd.read_csv('Data/Assignment 2_Households with 18 year old_ACS data.csv')

# %%
# What are the dimensions of the dataset?
children.shape
# Out:
# (197, 92)

# %%
# A quick snapshot of the data
children.head()
# Out:
#      Geo_FIPS           Geo_GEOID          Geo_NAME  \
# 0  6075010100  14000US06075010100  Census Tract 101
# 1  6075010200  14000US06075010200  Census Tract 102
# 2  6075010300  14000US06075010300  Census Tract 103
# 3  6075010400  14000US06075010400  Census Tract 104
# 4  6075010500  14000US06075010500  Census Tract 105
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 101, San Francisco County, Califo...         ca         140
# 1  Census Tract 102, San Francisco County, Califo...         ca         140
# 2  Census Tract 103, San Francisco County, Califo...         ca         140
# 3  Census Tract 104, San Francisco County, Califo...         ca         140
# 4  Census Tract 105, San Francisco County, Califo...         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  PCT_SE_A10009_010  \
# 0            0      ACSSF          8985     NaN  ...                0.0
# ...

# %%
# To take a look at all the columns of the dataset
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# One row to examine all the columns of the dataset
children.sample()
# Out:
#       Geo_FIPS           Geo_GEOID             Geo_NAME  \
# 31  6075012901  14000US06075012901  Census Tract 129.01
#
#                                             Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 31  Census Tract 129.01, San Francisco County, Cal...         ca         140
#
#     Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 31            0      ACSSF          9016     NaN         NaN           NaN
#
#     Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_PLACESE  \
# 31          NaN          6          75         NaN        NaN          NaN
#
#     Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  \
# 31      12901         NaN         NaN         NaN           NaN          NaN
#
#     Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  \
# 31         NaN       NaN       NaN       NaN      NaN         NaN       NaN
#
#     Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_UACP  \
# ...

# %%
# Check FIPS code to make see if leading zeros are missing
children.Geo_FIPS.head()
# Out:
# 0    6075010100
# 1    6075010200
# 2    6075010300
# 3    6075010400
# 4    6075010500
# Name: Geo_FIPS, dtype: int64

# %%
# Check State code to see if leading zeros are missing
children.Geo_STATE.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: Geo_STATE, dtype: int64

# %%
# Check County code to see if leading zeros are missing
children.Geo_COUNTY.head()
# Out:
# 0    75
# 1    75
# 2    75
# 3    75
# 4    75
# Name: Geo_COUNTY, dtype: int64

# %%
# Leading zeros are missing...must mean that the variables are read as integers instead of strings, so change data type for the relevant FIPS code components to strings
children = pd.read_csv(
            'Data/Assignment 2_Households with 18 year old_ACS data.csv',
            dtype= 
            {
                'Geo_FIPS':str,
                'Geo_STATE':str,
                'Geo_COUNTY':str
            }
)

# %%
# Check to make sure the code resulted in the proper data type conversion
children.head()
# Out:
#       Geo_FIPS           Geo_GEOID          Geo_NAME  \
# 0  06075010100  14000US06075010100  Census Tract 101
# 1  06075010200  14000US06075010200  Census Tract 102
# 2  06075010300  14000US06075010300  Census Tract 103
# 3  06075010400  14000US06075010400  Census Tract 104
# 4  06075010500  14000US06075010500  Census Tract 105
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 101, San Francisco County, Califo...         ca         140
# 1  Census Tract 102, San Francisco County, Califo...         ca         140
# 2  Census Tract 103, San Francisco County, Califo...         ca         140
# 3  Census Tract 104, San Francisco County, Califo...         ca         140
# 4  Census Tract 105, San Francisco County, Califo...         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          8985     NaN         NaN           NaN
# ...

# %%
# Check which columns have empty cells
children.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 92 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           197 non-null    object
#  1   Geo_GEOID          197 non-null    object
#  2   Geo_NAME           197 non-null    object
#  3   Geo_QName          197 non-null    object
#  4   Geo_STUSAB         197 non-null    object
#  5   Geo_SUMLEV         197 non-null    int64
#  6   Geo_GEOCOMP        197 non-null    int64
#  7   Geo_FILEID         197 non-null    object
#  8   Geo_LOGRECNO       197 non-null    int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          197 non-null    object
#  14  Geo_COUNTY         197 non-null    object
#  15  Geo_COUSUB         0 non-null      float64
# ...

# %%
# Check which columns have every cell empty
children.columns[children.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
# Drop all columns that have all empty cells
children = children.dropna(axis=1,how="all")

# %%
# Check to make sure all null columns were dropped 
children.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           197 non-null    object
#  1   Geo_GEOID          197 non-null    object
#  2   Geo_NAME           197 non-null    object
#  3   Geo_QName          197 non-null    object
#  4   Geo_STUSAB         197 non-null    object
#  5   Geo_SUMLEV         197 non-null    int64
#  6   Geo_GEOCOMP        197 non-null    int64
#  7   Geo_FILEID         197 non-null    object
#  8   Geo_LOGRECNO       197 non-null    int64
#  9   Geo_STATE          197 non-null    object
#  10  Geo_COUNTY         197 non-null    object
#  11  Geo_TRACT          197 non-null    int64
#  12  SE_A10009_001      197 non-null    int64
#  13  SE_A10009_002      197 non-null    int64
#  14  SE_A10009_003      197 non-null    int64
#  15  SE_A10009_004      197 non-null    int64
# ...

# %%
# Double check to make sure columns were dropped
children.head()
# Out:
#       Geo_FIPS           Geo_GEOID          Geo_NAME  \
# 0  06075010100  14000US06075010100  Census Tract 101
# 1  06075010200  14000US06075010200  Census Tract 102
# 2  06075010300  14000US06075010300  Census Tract 103
# 3  06075010400  14000US06075010400  Census Tract 104
# 4  06075010500  14000US06075010500  Census Tract 105
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 101, San Francisco County, Califo...         ca         140
# 1  Census Tract 102, San Francisco County, Califo...         ca         140
# 2  Census Tract 103, San Francisco County, Califo...         ca         140
# 3  Census Tract 104, San Francisco County, Califo...         ca         140
# 4  Census Tract 105, San Francisco County, Califo...         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO Geo_STATE Geo_COUNTY  Geo_TRACT  \
# 0            0      ACSSF          8985         6         75      10100
# ...

# %%
# Check the new dimensions of the dataset
children.shape
# Out:
# (197, 49)

# %%
# List irrelevant columns to drop
columns_to_drop = ['Geo_GEOID','Geo_STUSAB','Geo_SUMLEV','Geo_GEOCOMP','Geo_FILEID','Geo_LOGRECNO']

# %%
# Drop irrelevant columns listed above...we do this again later on
children=children.drop(columns_to_drop,axis=1)
children.head()
# Out:
#       Geo_FIPS          Geo_NAME  \
# 0  06075010100  Census Tract 101
# 1  06075010200  Census Tract 102
# 2  06075010300  Census Tract 103
# 3  06075010400  Census Tract 104
# 4  06075010500  Census Tract 105
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 101, San Francisco County, Califo...         6         75
# 1  Census Tract 102, San Francisco County, Califo...         6         75
# 2  Census Tract 103, San Francisco County, Califo...         6         75
# 3  Census Tract 104, San Francisco County, Califo...         6         75
# 4  Census Tract 105, San Francisco County, Califo...         6         75
#
#    Geo_TRACT  SE_A10009_001  SE_A10009_002  SE_A10009_003  SE_A10009_004  \
# 0      10100           2061            281            281            148
# 1      10200           2541            135            135            111
# 2      10300           1970            288            288            234
# ...

# %%
# List out the remaining columns
columns = list(children)
columns
# Out:
# ['Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_A10009_001',
#  'SE_A10009_002',
#  'SE_A10009_003',
#  'SE_A10009_004',
#  'SE_A10009_005',
#  'SE_A10009_006',
#  'SE_A10009_007',
#  'SE_A10009_008',
#  'SE_A10009_009',
#  'SE_A10009_010',
#  'SE_A10009_011',
#  'SE_A10009_012',
#  'SE_A10009_013',
#  'SE_A10009_014',
#  'SE_A10009_015',
#  'SE_A10009_016',
#  'SE_A10009_017',
#  'SE_A10009_018',
#  'SE_A10009_019',
#  'PCT_SE_A10009_002',
#  'PCT_SE_A10009_003',
#  'PCT_SE_A10009_004',
#  'PCT_SE_A10009_005',
#  'PCT_SE_A10009_006',
#  'PCT_SE_A10009_007',
#  'PCT_SE_A10009_008',
#  'PCT_SE_A10009_009',
#  'PCT_SE_A10009_010',
#  'PCT_SE_A10009_011',
#  'PCT_SE_A10009_012',
#  'PCT_SE_A10009_013',
#  'PCT_SE_A10009_014',
#  'PCT_SE_A10009_015',
#  'PCT_SE_A10009_016',
#  'PCT_SE_A10009_017',
#  'PCT_SE_A10009_018',
#  'PCT_SE_A10009_019']

# %%
# Rename columns so we know what they actually represent
children.columns =['FIPS',
 'Geo_NAME',
 'Geo_QName',
 'Geo_STATE',
 'Geo_COUNTY',
 'Geo_TRACT',
 'Households',
 'HH_One_or_More_Under_18',
 'Family_HH',
 'Married_Couple_Family',
 'Single_Parent',
 'Single_Parent_Male_HH',
 'Single_Parent_Female_HH',
 'SE_A10009_008',
 'SE_A10009_009',
 'SE_A10009_010',
 'SE_A10009_011',
 'SE_A10009_012',
 'SE_A10009_013',
 'SE_A10009_014',
 'SE_A10009_015',
 'SE_A10009_016',
 'SE_A10009_017',
 'SE_A10009_018',
 'SE_A10009_019',
 'PCT_Family_HH',
 'PCT_HH_One_or_More_Under_18',
 'PCT_Married_Couple_Family',
 'PCT_Single_Parent',
 'PCT_Single_Parent_Male_HH',
 'PCT_Single_Parent_Female_HH',
 'PCT_SE_A10009_008',
'PCT_SE_A10009_009',
 'PCT_SE_A10009_010',
 'PCT_SE_A10009_011',
 'PCT_SE_A10009_012',
 'PCT_SE_A10009_013',
 'PCT_SE_A10009_014',
 'PCT_SE_A10009_015',
 'PCT_SE_A10009_016',
 'PCT_SE_A10009_017',
 'PCT_SE_A10009_018',
 'PCT_SE_A10009_019']

# %%
# Check to make sure columns were in fact renamed
children.head()
# Out:
#           FIPS          Geo_NAME  \
# 0  06075010100  Census Tract 101
# 1  06075010200  Census Tract 102
# 2  06075010300  Census Tract 103
# 3  06075010400  Census Tract 104
# 4  06075010500  Census Tract 105
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 101, San Francisco County, Califo...         6         75
# 1  Census Tract 102, San Francisco County, Califo...         6         75
# 2  Census Tract 103, San Francisco County, Califo...         6         75
# 3  Census Tract 104, San Francisco County, Califo...         6         75
# 4  Census Tract 105, San Francisco County, Califo...         6         75
#
#    Geo_TRACT  Households  HH_One_or_More_Under_18  Family_HH  \
# 0      10100        2061                      281        281
# 1      10200        2541                      135        135
# 2      10300        1970                      288        288
# 3      10400        2418                      266        266
# ...

# %%
# Pull snapshot data of an individual column
children.Households.head()
# Out:
# 0    2061
# 1    2541
# 2    1970
# 3    2418
# 4    1717
# Name: Households, dtype: int64

# %%
# Calculate the mean of the number of households in SF County
children.Households.mean()
# Out:
# 1825.751269035533

# %%
# Calculate descriptive statistics for the number of households in SF County
children.Households.describe()
# Out:
# count     197.000000
# mean     1825.751269
# std       870.239625
# min         0.000000
# 25%      1384.000000
# 50%      1795.000000
# 75%      2291.000000
# max      7900.000000
# Name: Households, dtype: float64

# %%
# Plot a histogram of the number of households in SF County 
children.Households.plot.hist(bins=50)

# %%
# Plot a histogram of the number of Single Parent Households in SF County
children.Single_Parent.plot.hist(bins=50)

# %%
# Check how many rows there are of the dataset
len(children)
# Out:
# 197

# %%
# Which rows have some empty cells
children.isna().sum()
# Out:
# FIPS                           0
# Geo_NAME                       0
# Geo_QName                      0
# Geo_STATE                      0
# Geo_COUNTY                     0
# Geo_TRACT                      0
# Households                     0
# HH_One_or_More_Under_18        0
# Family_HH                      0
# Married_Couple_Family          0
# Single_Parent                  0
# Single_Parent_Male_HH          0
# Single_Parent_Female_HH        0
# SE_A10009_008                  0
# SE_A10009_009                  0
# SE_A10009_010                  0
# SE_A10009_011                  0
# SE_A10009_012                  0
# SE_A10009_013                  0
# SE_A10009_014                  0
# SE_A10009_015                  0
# SE_A10009_016                  0
# SE_A10009_017                  0
# SE_A10009_018                  0
# SE_A10009_019                  0
# PCT_Family_HH                  2
# PCT_HH_One_or_More_Under_18    2
# PCT_Married_Couple_Family      2
# ...

# %%
# Output the rows in the PCT_Family_HH column with null values
children[children['PCT_Family_HH'].isnull()]
# Out:
#             FIPS              Geo_NAME  \
# 192  06075980401  Census Tract 9804.01
# 196  06075990100     Census Tract 9901
#
#                                              Geo_QName Geo_STATE Geo_COUNTY  \
# 192  Census Tract 9804.01, San Francisco County, Ca...         6         75
# 196  Census Tract 9901, San Francisco County, Calif...         6         75
#
#      Geo_TRACT  Households  HH_One_or_More_Under_18  Family_HH  \
# 192     980401           0                        0          0
# 196     990100           0                        0          0
#
#      Married_Couple_Family  Single_Parent  Single_Parent_Male_HH  \
# 192                      0              0                      0
# 196                      0              0                      0
#
#      Single_Parent_Female_HH  SE_A10009_008  SE_A10009_009  SE_A10009_010  \
# 192                        0              0              0              0
# ...

# %%
# Output the rows in the PCT_Married_Couple_Family column with null values 
children[children['PCT_Married_Couple_Family'].isnull()]
# Out:
#             FIPS              Geo_NAME  \
# 192  06075980401  Census Tract 9804.01
# 196  06075990100     Census Tract 9901
#
#                                              Geo_QName Geo_STATE Geo_COUNTY  \
# 192  Census Tract 9804.01, San Francisco County, Ca...         6         75
# 196  Census Tract 9901, San Francisco County, Calif...         6         75
#
#      Geo_TRACT  Households  HH_One_or_More_Under_18  Family_HH  \
# 192     980401           0                        0          0
# 196     990100           0                        0          0
#
#      Married_Couple_Family  Single_Parent  Single_Parent_Male_HH  \
# 192                      0              0                      0
# 196                      0              0                      0
#
#      Single_Parent_Female_HH  SE_A10009_008  SE_A10009_009  SE_A10009_010  \
# 192                        0              0              0              0
# ...

# %%
# Sort rows by the number of households from highest to lowest
children_sorted = children.sort_values(by='Households',ascending = False)
children_sorted
# Out:
#             FIPS              Geo_NAME  \
# 189  06075061500      Census Tract 615
# 184  06075060700      Census Tract 607
# 64   06075017601   Census Tract 176.01
# 70   06075020100      Census Tract 201
# 10   06075011100      Census Tract 111
# 71   06075020200      Census Tract 202
# 173  06075045200      Census Tract 452
# 43   06075015400      Census Tract 154
# 161  06075035100      Census Tract 351
# 156  06075033000      Census Tract 330
# 111  06075025500      Census Tract 255
# 23   06075012401   Census Tract 124.01
# 76   06075020600      Census Tract 206
# 78   06075020800      Census Tract 208
# 139  06075030700      Census Tract 307
# 19   06075012201   Census Tract 122.01
# 179  06075047901   Census Tract 479.01
# 24   06075012402   Census Tract 124.02
# 46   06075015700      Census Tract 157
# 164  06075035300      Census Tract 353
# 165  06075035400      Census Tract 354
# 8    06075010900      Census Tract 109
# 51   06075016100      Census Tract 161
# ...

# %%
# Plot the number of households
children.Households.plot()

# %%
# Output specific columns from the sorted dataset
children_sorted[['PCT_Family_HH','PCT_HH_One_or_More_Under_18', 'PCT_Married_Couple_Family']].head(10)
# Out:
#      PCT_Family_HH  PCT_HH_One_or_More_Under_18  PCT_Married_Couple_Family
# 189          10.95                        10.95                       9.77
# 184          15.72                        15.72                      12.06
# 64           11.08                        11.08                       7.47
# 70           10.34                        10.34                       5.53
# 10            3.91                         3.91                       3.24
# 71           14.13                        13.17                       7.57
# 173          16.90                        16.90                      12.71
# 43           17.07                        17.07                      16.65
# 161          30.54                        30.54                      22.42
# 156          31.27                        30.67                      26.88

# %%
# Output specific columns from the sorted dataset
children_sorted[['Geo_NAME','Households','HH_One_or_More_Under_18','Family_HH','Married_Couple_Family']].head(10)
# Out:
#                 Geo_NAME  Households  HH_One_or_More_Under_18  Family_HH  \
# 189     Census Tract 615        7900                      865        865
# 184     Census Tract 607        5870                      923        923
# 64   Census Tract 176.01        5273                      584        584
# 70      Census Tract 201        3309                      342        342
# 10      Census Tract 111        3144                      123        123
# 71      Census Tract 202        3143                      444        414
# 173     Census Tract 452        2958                      500        500
# 43      Census Tract 154        2865                      489        489
# 161     Census Tract 351        2855                      872        872
# 156     Census Tract 330        2824                      883        866
#
#      Married_Couple_Family
# 189                    772
# 184                    708
# 64                     394
# 70                     183
# ...

# %%
# Create a bar graph of the number of Married Couple households among the top 10 census tracts with the most number of households
children_sorted.head(10).plot.bar(x='Geo_NAME',
                                 y='Married_Couple_Family')

# %%
# Create a bar graph of the Top 10 Census Tracts with the Highest Number of Households in SF Coumty
children_sorted.head(10).plot.bar(x='Geo_NAME',
                                 y= 'Households',
                                 title= 'Top 10 Census Tracts with Highest Number of Households in San Francisco County')

# %%
# Output data for Census tracts with more than 2000 household
children[children['Households']>=2000]
# Out:
#             FIPS             Geo_NAME  \
# 0    06075010100     Census Tract 101
# 1    06075010200     Census Tract 102
# 3    06075010400     Census Tract 104
# 6    06075010700     Census Tract 107
# 7    06075010800     Census Tract 108
# 8    06075010900     Census Tract 109
# 9    06075011000     Census Tract 110
# 10   06075011100     Census Tract 111
# 17   06075012000     Census Tract 120
# 18   06075012100     Census Tract 121
# 19   06075012201  Census Tract 122.01
# 23   06075012401  Census Tract 124.01
# 24   06075012402  Census Tract 124.02
# 25   06075012501  Census Tract 125.01
# 26   06075012502  Census Tract 125.02
# 29   06075012700     Census Tract 127
# 30   06075012800     Census Tract 128
# 32   06075012902  Census Tract 129.02
# 33   06075013000     Census Tract 130
# 34   06075013101  Census Tract 131.01
# 36   06075013200     Census Tract 132
# 41   06075015200     Census Tract 152
# 43   06075015400     Census Tract 154
# ...

# %%
# How many Census tracts have more than 5 percent of households being single parent households?
children_pct_single_parent = children[children['PCT_Single_Parent']>5]
children_pct_single_parent[['Geo_NAME','PCT_Single_Parent']]
print('There are ' + str(len(children_pct_single_parent))+' census tracts with more than 5 percent of households being single parent households')
children_pct_single_parent[['Geo_NAME','PCT_Single_Parent']].head(10).sort_values(by='PCT_Single_Parent',ascending=False)
# Out:
# There are 79 census tracts with more than 5 percent of households being single parent households
#                Geo_NAME  PCT_Single_Parent
# 47  Census Tract 158.01              12.11
# 51     Census Tract 161               8.77
# 25  Census Tract 125.01               7.48
# 57     Census Tract 167               6.99
# 42     Census Tract 153               6.54
# 0      Census Tract 101               6.45
# 12     Census Tract 113               5.37
# 37     Census Tract 133               5.17
# 32  Census Tract 129.02               5.10
# 14     Census Tract 118               5.03

# %%
import geopandas as gpd

# %%
# Relative file path to upload SF boundaries data (2010 Census data from data.sfgov.org)
tracts=gpd.read_file('Data/Assignment 2_Census 2010_ Tracts for San Francisco.geojson')
tracts.head()
# Out:
#   statefp10 mtfcc10 name10   intptlat10 awater10        namelsad10 funcstat10  \
# 0        06   G5020    165  +37.7741958        0  Census Tract 165          S
# 1        06   G5020    164  +37.7750995        0  Census Tract 164          S
# 2        06   G5020    163  +37.7760456        0  Census Tract 163          S
# 3        06   G5020    161  +37.7799831        0  Census Tract 161          S
# 4        06   G5020    160  +37.7823363        0  Census Tract 160          S
#
#   aland10      geoid10 tractce10    intptlon10 countyfp10  \
# 0  370459  06075016500    016500  -122.4477884        075
# 1  309097  06075016400    016400  -122.4369729        075
# 2  245867  06075016300    016300  -122.4295509        075
# 3  368901  06075016100    016100  -122.4286631        075
# 4  158236  06075016000    016000  -122.4224838        075
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# ...

# %%
# Any columns that have null values?
tracts.info(verbose=True,null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   statefp10   197 non-null    object
#  1   mtfcc10     197 non-null    object
#  2   name10      197 non-null    object
#  3   intptlat10  197 non-null    object
#  4   awater10    197 non-null    object
#  5   namelsad10  197 non-null    object
#  6   funcstat10  197 non-null    object
#  7   aland10     197 non-null    object
#  8   geoid10     197 non-null    object
#  9   tractce10   197 non-null    object
#  10  intptlon10  197 non-null    object
#  11  countyfp10  197 non-null    object
#  12  geometry    197 non-null    geometry
# dtypes: geometry(1), object(12)
# memory usage: 20.1+ KB

# %%
# Check dimensions of dataset
tracts.shape
# Out:
# (197, 13)

# %%
# Output the relevant columns
tracts = tracts[['geoid10','geometry']]
tracts.head()
# Out:
#        geoid10                                           geometry
# 0  06075016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1  06075016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2  06075016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3  06075016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4  06075016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...

# %%
# Rename columns
tracts.columns=['FIPS','geometry']

# %%
# Check to make sure columns were renamed
tracts.head()
# Out:
#           FIPS                                           geometry
# 0  06075016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1  06075016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2  06075016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3  06075016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4  06075016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...

# %%
# Plot geospatial data
tracts.plot(figsize=(12,10))

# %%
# Merge the two datasets and redefine 
tracts_HH=tracts.merge(children,on='FIPS')

# %%
# Check and output data from newly merged dataset 
tracts_HH.head()
# Out:
#           FIPS                                           geometry  \
# 0  06075016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1  06075016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2  06075016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3  06075016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4  06075016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...
#
#            Geo_NAME                                          Geo_QName  \
# 0  Census Tract 165  Census Tract 165, San Francisco County, Califo...
# 1  Census Tract 164  Census Tract 164, San Francisco County, Califo...
# 2  Census Tract 163  Census Tract 163, San Francisco County, Califo...
# 3  Census Tract 161  Census Tract 161, San Francisco County, Califo...
# 4  Census Tract 160  Census Tract 160, San Francisco County, Califo...
#
#   Geo_STATE Geo_COUNTY  Geo_TRACT  Households  HH_One_or_More_Under_18  \
# ...

# %%
# Identify any remaining irrelevant columns to drop
columns_to_drop=['SE_A10009_008','SE_A10009_009','SE_A10009_010','SE_A10009_011','SE_A10009_012','SE_A10009_013','SE_A10009_014','SE_A10009_015','SE_A10009_016','SE_A10009_017','SE_A10009_018','SE_A10009_019','PCT_SE_A10009_008','PCT_SE_A10009_009','PCT_SE_A10009_010','PCT_SE_A10009_011','PCT_SE_A10009_012','PCT_SE_A10009_013','PCT_SE_A10009_014','PCT_SE_A10009_015','PCT_SE_A10009_016','PCT_SE_A10009_017','PCT_SE_A10009_018','PCT_SE_A10009_019']

# %%
# Drop any remaining irrelevant columns
tracts_HH=tracts_HH.drop(columns_to_drop,axis=1)
tracts_HH.head()
# Out:
#           FIPS                                           geometry  \
# 0  06075016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1  06075016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2  06075016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3  06075016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4  06075016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...
#
#            Geo_NAME                                          Geo_QName  \
# 0  Census Tract 165  Census Tract 165, San Francisco County, Califo...
# 1  Census Tract 164  Census Tract 164, San Francisco County, Califo...
# 2  Census Tract 163  Census Tract 163, San Francisco County, Califo...
# 3  Census Tract 161  Census Tract 161, San Francisco County, Califo...
# 4  Census Tract 160  Census Tract 160, San Francisco County, Califo...
#
#   Geo_STATE Geo_COUNTY  Geo_TRACT  Households  HH_One_or_More_Under_18  \
# ...

# %%
# Create a map illustrating the number of Married Couple households per a Census tract
tracts_HH.plot(figsize=(12,10),
                column='Married_Couple_Family',
                legend=True,
                scheme='NaturalBreaks')

# %%
# Create a map illustrating the number of Married Couple households per a Census tract
tracts_HH.plot(figsize=(12,10),
                column='Married_Couple_Family',
                legend=True,
                scheme='equal_interval')

# %%
# Create a map illustrating the number of Single Male Parent households per a Census tract
tracts_HH.plot(figsize=(12,10),
                column='Single_Parent_Male_HH',
                legend=True,
                scheme='NaturalBreaks')

# %%
# Create a map illustrating the number of Single Female Parent households per a Census tract
tracts_HH.plot(figsize=(15,13),
                column='Single_Parent_Female_HH',
                legend=True,
                scheme='NaturalBreaks')

# %%
# Create a map illustrating the number of Households per a Census tract
tracts_HH.plot(figsize=(12,10),
                column='Households',
                legend=True,
                scheme='NaturalBreaks')

# %%
# Output data for Census tracts where Single Female Parent househodls account for more than 5% of households
tracts_HH[tracts_HH.PCT_Single_Parent_Female_HH>5]
# Out:
#             FIPS                                           geometry  \
# 3    06075016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 11   06075015300  MULTIPOLYGON (((-122.43492 37.78588, -122.4365...
# 16   06075013300  MULTIPOLYGON (((-122.44559 37.78836, -122.4454...
# 25   06075011800  MULTIPOLYGON (((-122.40442 37.79264, -122.4056...
# 35   06075980600  MULTIPOLYGON (((-122.37258 37.72925, -122.3722...
# 36   06075980501  MULTIPOLYGON (((-122.42674 37.71122, -122.4265...
# 40   06075980900  MULTIPOLYGON (((-122.37412 37.74497, -122.3761...
# 45   06075010100  MULTIPOLYGON (((-122.42108 37.81289, -122.4201...
# 47   06075061400  MULTIPOLYGON (((-122.39153 37.75261, -122.3916...
# 50   06075061200  MULTIPOLYGON (((-122.38904 37.73292, -122.3909...
# 55   06075042601  MULTIPOLYGON (((-122.48300 37.78583, -122.4819...
# 58   06075032902  MULTIPOLYGON (((-122.48599 37.75195, -122.4858...
# 60   06075032802  MULTIPOLYGON (((-122.47713 37.75608, -122.4765...
# ...

# %%
# Create map for Census tracts where Single Female Parent househodls account for more than 5% of households
tracts_HH[tracts_HH.PCT_Single_Parent_Female_HH>5].plot(figsize=(12,10),
                                                       column='PCT_Single_Parent_Female_HH',
                                                       legend=True,
                                                       scheme='equal_interval')

# %%
# Create map for Census tracts where Single Male Parent househodls account for more than 5% of households
tracts_HH[tracts_HH.PCT_Single_Parent_Male_HH>5].plot(figsize=(12,10),
                                                       column='PCT_Single_Parent_Male_HH',
                                                       legend=True,
                                                       scheme='equal_interval')

# %%
# Create map for Census tracts where greater than 5% of households have at least one child
tracts_HH[tracts_HH.PCT_HH_One_or_More_Under_18>5].plot(figsize=(12,10),
                                                       column='PCT_HH_One_or_More_Under_18',
                                                       legend=True,
                                                       scheme='equal_interval')

# %%
# Sort data by percent of households with at least one child from highest to lowest
children_sorted = children.sort_values(by='PCT_HH_One_or_More_Under_18', ascending=False)
children_sorted
# Out:
#             FIPS              Geo_NAME  \
# 183  06075060502   Census Tract 605.02
# 101  06075023103   Census Tract 231.03
# 104  06075023400      Census Tract 234
# 110  06075025403   Census Tract 254.03
# 117  06075026001   Census Tract 260.01
# 181  06075060100      Census Tract 601
# 129  06075026404   Census Tract 264.04
# 100  06075023102   Census Tract 231.02
# 171  06075042800      Census Tract 428
# 126  06075026401   Census Tract 264.01
# 127  06075026402   Census Tract 264.02
# 125  06075026303   Census Tract 263.03
# 98   06075023001   Census Tract 230.01
# 103  06075023300      Census Tract 233
# 120  06075026004   Census Tract 260.04
# 138  06075030600      Census Tract 306
# 102  06075023200      Census Tract 232
# 128  06075026403   Census Tract 264.03
# 141  06075030900      Census Tract 309
# 111  06075025500      Census Tract 255
# 118  06075026002   Census Tract 260.02
# 119  06075026003   Census Tract 260.03
# 188  06075061400      Census Tract 614
# ...

# %%
# Create a bar graph of Top 10 Census tracts with highest percent of households with children 
children_sorted.head(10).plot.bar(x='Geo_NAME',
                                 y='PCT_HH_One_or_More_Under_18',
                                 title='Top 10 Census Tracts with Highest Percent of Households with Children')

# %%
import folium

# %%
# Create a folium Choropleth map of the percent of households with at least one child by Census tract in SF County
# The map does not output for some reason, but when saved and opened as an HTML it becomes visible and interactive
m = folium.Map(location =[37.7749,-122.4194],
              zoom_start=9,
              tiles='OpenStreetMap')
folium.Choropleth(
                    geo_data=tracts_HH,
                    data=tracts_HH,
                    key_on='feature.properties.FIPS',
                    columns=['FIPS','PCT_HH_One_or_More_Under_18'],
                    fill_color='BuPu',
                    line_weight=0.1,
                    fill_opacity=0.8,
                    line_opacity=0.2,
                    legend_name='Percent of Households With One or More Children (2014-2018 ACS 5-Year Estimates').add_to(m)

# %%
# Save map as an HTML
m.save('SF_PCT_HH_Atleast_One_Child.html')

# %%
https://jupyter.idre.ucla.edu/user/stohamy@ucla.edu/view/personal/SF_PCT_HH_Atleast_One_Child.html
